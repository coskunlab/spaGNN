# %%
import scanpy as sc
import anndata
import numpy as np
import seaborn as sns
from matplotlib.pyplot import rc_context
import matplotlib.pyplot as plt
import tifffile
import skimage.io as io

import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans, AgglomerativeClustering

from tqdm import tqdm
import pickle
import os

# %%
adata = anndata.read_h5ad(filename=r'..\results\HCH\patches\hch_006_1 clustered data.h5ad')

# %%
adata.obs['leiden']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 7888     5
# 7889    18
# 7890    18
# 7891    20
# 7892    18
# Name: leiden, Length: 7893, dtype: category
# Categories (41, object): ['0', '1', '2', '3', ..., '37', '38', '39', '40']

# %%
for i in range(41):
    with rc_context({'figure.figsize': (10, 10), 'font.size': 35, 'axes.edgecolor': '0.15', 'axes.linewidth': 1.25, 'axes.facecolor': '#FFFFFF'}):
        sc.pl.spatial(adata, color="leiden", groups=[str(i)], spot_size=10, legend_fontsize=25, save='hch_006_1 patch '+str(i)+'.png')
# Out:
# WARNING: saving figure to file figures\showhch_005_8 patch 0.png
# WARNING: saving figure to file figures\showhch_005_8 patch 1.png
# WARNING: saving figure to file figures\showhch_005_8 patch 2.png
# WARNING: saving figure to file figures\showhch_005_8 patch 3.png
# WARNING: saving figure to file figures\showhch_005_8 patch 4.png
# WARNING: saving figure to file figures\showhch_005_8 patch 5.png
# WARNING: saving figure to file figures\showhch_005_8 patch 6.png
# WARNING: saving figure to file figures\showhch_005_8 patch 7.png
# WARNING: saving figure to file figures\showhch_005_8 patch 8.png
# WARNING: saving figure to file figures\showhch_005_8 patch 9.png
# WARNING: saving figure to file figures\showhch_005_8 patch 10.png
# WARNING: saving figure to file figures\showhch_005_8 patch 11.png
# WARNING: saving figure to file figures\showhch_005_8 patch 12.png
# WARNING: saving figure to file figures\showhch_005_8 patch 13.png
# WARNING: saving figure to file figures\showhch_005_8 patch 14.png
# WARNING: saving figure to file figures\showhch_005_8 patch 15.png
# WARNING: saving figure to file figures\showhch_005_8 patch 16.png
# WARNING: saving figure to file figures\showhch_005_8 patch 17.png
# WARNING: saving figure to file figures\showhch_005_8 patch 18.png
# WARNING: saving figure to file figures\showhch_005_8 patch 19.png
# WARNING: saving figure to file figures\showhch_005_8 patch 20.png
# WARNING: saving figure to file figures\showhch_005_8 patch 21.png
# WARNING: saving figure to file figures\showhch_005_8 patch 22.png
# WARNING: saving figure to file figures\showhch_005_8 patch 23.png
# WARNING: saving figure to file figures\showhch_005_8 patch 24.png
# WARNING: saving figure to file figures\showhch_005_8 patch 25.png
# WARNING: saving figure to file figures\showhch_005_8 patch 26.png
# WARNING: saving figure to file figures\showhch_005_8 patch 27.png
# WARNING: saving figure to file figures\showhch_005_8 patch 28.png
# WARNING: saving figure to file figures\showhch_005_8 patch 29.png
# WARNING: saving figure to file figures\showhch_005_8 patch 30.png
# WARNING: saving figure to file figures\showhch_005_8 patch 31.png
# WARNING: saving figure to file figures\showhch_005_8 patch 32.png
# WARNING: saving figure to file figures\showhch_005_8 patch 33.png
# WARNING: saving figure to file figures\showhch_005_8 patch 34.png
# WARNING: saving figure to file figures\showhch_005_8 patch 35.png
# WARNING: saving figure to file figures\showhch_005_8 patch 36.png
# WARNING: saving figure to file figures\showhch_005_8 patch 37.png
# WARNING: saving figure to file figures\showhch_005_8 patch 38.png
# WARNING: saving figure to file figures\showhch_005_8 patch 39.png
# WARNING: saving figure to file figures\showhch_005_8 patch 40.png

# %%
with rc_context({'figure.figsize': (10, 10), 'font.size': 35, 'axes.edgecolor': '0.15', 'axes.linewidth': 1.25, 'axes.facecolor': '#FFFFFF'}):
    sc.pl.spatial(adata, color="leiden", groups=['0','1','3','6','16','20'], spot_size=10, legend_fontsize=35, save=' hch_006_1 highlighted patches v2.png')
# Out:
# WARNING: saving figure to file figures\show hch_005_8 highlighted patches v2.png

# %%
# Load dot locations
fn = r'..\results\HCH\detected_dots\hch_006_1.pkl'
cell = pd.read_pickle(fn)

# %%
neighborhood = adata.obs['leiden'].tolist()
neighborhood = [int(item) for item in neighborhood]

# %%
new_dic = {}
for k in cell.keys():
    df = pd.DataFrame(cell[k])
    df.columns = ['row', 'column']
    df['cluster'] = neighborhood[:df.shape[0]]
    neighborhood = neighborhood[df.shape[0]:]
    new_dic[k] = df

# %%
df = None
for k in new_dic.keys():
    if df is None:
        t = new_dic[k]
        t['gene'] = [k]*t.shape[0]
        df = t
    else:
        t = new_dic[k]
        t['gene'] = [k]*t.shape[0]
        df = pd.concat([df, t])

# %%
df
# Out:
#      row  column  cluster   gene
# 0    147     714       37    IL8
# 1    218     269       38    IL8
# 2    220     269       38    IL8
# 3    226     271       38    IL8
# 4    228     269       38    IL8
# ..   ...     ...      ...    ...
# 32  1032    1640       45  NANOG
# 33  1199    1498       32  NANOG
# 34  1204    1422       32  NANOG
# 35  1306    1747       54  NANOG
# 36  1457    1587       43  NANOG
#
# [12112 rows x 4 columns]

# %%
n_clusters = len(np.unique(adata.obs['leiden'].tolist()))
rna_neighbor_exp = np.zeros((n_clusters, 16))
genes = []
i = 0
markers_l = []
for k in new_dic.keys():
    genes.append(k)
    for j in range(n_clusters):
         rna_neighbor_exp[j,i] = sum(item==j for item in new_dic[k]['cluster'].tolist())
    i = i + 1
# Out:
# C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   if __name__ == '__main__':

# %%
def proximity_network(cluster_rna_df, n_neighbors):
    r = cluster_rna_df['row'].tolist()
    c = cluster_rna_df['column'].tolist()
    r_c = list(zip(r,c))
    neigh = NearestNeighbors(n_neighbors=n_neighbors)
    neigh.fit(r_c)
    dist, neighbors = neigh.kneighbors(r_c)
    
    genes = cluster_rna_df['gene'].tolist()
    markers_l = list(np.unique(genes))
    counts = np.zeros((cluster_rna_df.shape[0], len(markers_l)))
    for i in range(neighbors.shape[0]):
        for j in range(neighbors.shape[1]):
            neighbor = neighbors[i,j]
            idx = markers_l.index(genes[neighbor])
            counts[i,idx] = counts[i,idx] + 1
    df = pd.DataFrame(counts, columns=markers_l)
    return df.corr(method='pearson')

# %%
corr_l = []
for i in range(n_clusters-1):
    corr_l.append(proximity_network(df.loc[df['cluster']==i], n_neighbors=10))

# %%
df.loc[df['cluster']==i]
# Out:
#      row  column  cluster   gene
# 6    271     382        8    IL8
# 3    357     360        8  CCL11
# 1    396     403        8   SOX9
# 90   298     555        8   ACTB
# 132  327     366        8   ACTB
# ..   ...     ...      ...    ...
# 255  412     479        8  GAPDH
# 257  415     442        8  GAPDH
# 258  416     437        8  GAPDH
# 263  419     438        8  GAPDH
# 279  431     530        8  GAPDH
#
# [287 rows x 4 columns]

# %%
out_dir = r'..\results\HCH\neighborhood_networks\connectivity'

# %%
with open(os.path.join(out_dir, 'hch_006_1 neighborhoods_10_neighbors.pkl'), 'wb') as f:
    pickle.dump(corr_l, f)

# %%
temp = df.loc[df['cluster']==10]

# %%
r = temp['row'].tolist()
c = temp['column'].tolist()

# %%
r_c = list(zip(r,c))
neigh = NearestNeighbors(n_neighbors=10)
neigh.fit(r_c)
dist, neighbors = neigh.kneighbors(r_c)

# %%
temp = pd.read_pickle(r'..\results\HCH\neighborhood_networks\connectivity\hch_006_1 neighborhoods_10_neighbors.pkl')

# %%
corr = temp[0]

# %%
sns.set(font_scale=2.5)
sns.clustermap(corr, cmap='vlag')
# plt.savefig(r'.\\figures\\exp2_uc_017_1_correlation.png')

# %% [markdown]
# # Visualize nearet neighbor

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 12112 × 2
#     obs: 'leiden'
#     uns: 'leiden', 'neighbors', 'leiden_colors'
#     obsm: 'spatial'
#     obsp: 'connectivities', 'distances'

# %%
patches = adata.obs['leiden'].tolist()
colors = adata.uns['leiden_colors']
points = adata.X
dot_colors = adata.uns['leiden_colors']

# %%
points.shape
# Out:
# (12112, 2)

# %%
patch_df = df.loc[df['cluster']==6]

# %%
patch_df
# Out:
#        row  column  cluster   gene
# 3788  1026    1394        6   ACTB
# 3846  1032    1391        6   ACTB
# 3858  1033    1381        6   ACTB
# 3873  1035    1415        6   ACTB
# 3888  1036    1412        6   ACTB
# ...    ...     ...      ...    ...
# 2953  1125    1453        6  GAPDH
# 2963  1128    1426        6  GAPDH
# 2965  1129    1455        6  GAPDH
# 2970  1130    1447        6  GAPDH
# 2973  1131    1439        6  GAPDH
#
# [291 rows x 4 columns]

# %%
r = patch_df['row'].tolist()
c = patch_df['column'].tolist()
r_c = list(zip(r,c))

# %%
m = np.mean(r_c, axis=0).reshape(1,2)
neigh = NearestNeighbors(n_neighbors=1)
neigh.fit(r_c)
dist, neighbors = neigh.kneighbors(m)

# %%
neighbors
# Out:
# array([[78]], dtype=int64)

# %%
c = r_c[78]
c = np.array(c).reshape(1,2)

# %%
neigh = NearestNeighbors(n_neighbors=10)
neigh.fit(r_c)
dist, neighbors = neigh.kneighbors(c)

# %%
patch_df
# Out:
#        row  column  cluster   gene
# 3788  1026    1394        6   ACTB
# 3846  1032    1391        6   ACTB
# 3858  1033    1381        6   ACTB
# 3873  1035    1415        6   ACTB
# 3888  1036    1412        6   ACTB
# ...    ...     ...      ...    ...
# 2953  1125    1453        6  GAPDH
# 2963  1128    1426        6  GAPDH
# 2965  1129    1455        6  GAPDH
# 2970  1130    1447        6  GAPDH
# 2973  1131    1439        6  GAPDH
#
# [291 rows x 4 columns]

# %%
gene_color_dict = {'GAPDH': '#ffffff',
                   'ACTB': '#c34fff',
                   'IL8': '01a5ca',
                   'IL6': '#ec9d00',
                   'CCL11': '#ff7598',
                   'COL1A1': '#a6a19a',
                   'SPP1': '#edb7ff',
                   'SOX9': '#fff585',
                   'EEF2': '#92b853',
                   'NANOG': '#abd4ff',
                   'RUNX1': '#ff5401',
                   'PDL1': '#ffc3a6'
                  }

# %%
raw_im = tifffile.imread(r'..\images\HCH\adjusted\006\00_nucleus_hch_006.tif')

# %%
for i in range(10):
    print(patch_df.iloc[neighbors[0,i]])
# Out:
# row        1085
# column     1434
# cluster       6
# gene       ACTB
# Name: 4321, dtype: object
# row         1087
# column      1434
# cluster        6
# gene       GAPDH
# Name: 2779, dtype: object
# row         1083
# column      1435
# cluster        6
# gene       GAPDH
# Name: 2754, dtype: object
# row        1084
# column     1437
# cluster       6
# gene       ACTB
# Name: 4312, dtype: object
# row        1089
# column     1432
# cluster       6
# gene       ACTB
# Name: 4354, dtype: object
# row         1082
# column      1438
# cluster        6
# gene       RUNX1
# Name: 638, dtype: object
# row        1090
# column     1437
# cluster       6
# gene       ACTB
# Name: 4362, dtype: object
# row        1079
# column     1431
# cluster       6
# gene       ACTB
# Name: 4266, dtype: object
# row         1084
# column      1441
# cluster        6
# gene       GAPDH
# Name: 2761, dtype: object
# row        1089
# column     1428
# cluster       6
# gene       ACTB
# Name: 4353, dtype: object

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
ax.imshow(raw_im, cmap=plt.cm.gray)
ax.grid(False)
# ax.plot(l[:,1]-1000, l[:,0]-840, 'ro')

legends = []
for k in gene_color_dict.keys():
    color = gene_color_dict[k]
    if k in patch_df['gene'].tolist():
        sub_df = patch_df.loc[patch_df['gene']==k]
        ax.plot(sub_df['column'].values, sub_df['row'].values, 'o', color=color, label=k)
        legends.append(k)

for i in range(neighbors.shape[1]-1):
    point0 = r_c[neighbors[0,0]]
    point1 = r_c[neighbors[0,i+1]]
    ax.plot([point0[1],point1[1]], [point0[0],point1[0]], 'w-', linewidth=3, alpha=0.8)

ax.get_yaxis().set_ticks([])
ax.get_xaxis().set_ticks([])
ax.set_xlim(xmin=1000,xmax=1150)
ax.set_ylim(ymin=975, ymax=825)
legend = ax.legend(loc=0, bbox_to_anchor=(1,0.8), ncol=2)
frame = legend.get_frame()
frame.set_facecolor('black')
text = legend.get_texts()
for l in text:
    l.set_color('white')
plt.tight_layout()
plt.savefig('col-pos nearest neighbor visual.png')
plt.show()

# %% [markdown]
# # Batch Network Inference

# %%
cluster_dir = r'..\results\HCH\patches'
dot_dir = r'..\results\HCH\detected_dots'
out_dir = r'..\results\HCH\neighborhood_networks\connectivity'
fn_l = os.listdir(cluster_dir)
fn_l.sort()
fn_l2 = os.listdir(dot_dir)
fn_l2.sort()

# %%
n_markers_hch = 16
n_markers_msc = 12

# %%
for fn in tqdm(fn_l):
    adata = None
    if fn.endswith('.h5ad'):
        adata = anndata.read_h5ad(filename=os.path.join(cluster_dir, fn))
        name = fn.split(' ')[0]
        cell = pd.read_pickle(os.path.join(dot_dir, name+'.pkl'))
    else:
        continue
    neighborhood = adata.obs['leiden'].tolist()
    neighborhood = [int(item) for item in neighborhood]
    new_dic = {}
    for k in cell.keys():
        df = pd.DataFrame(cell[k])
        if len(cell[k]) == 0:
            continue
        df.columns = ['row', 'column']
        df['cluster'] = neighborhood[:df.shape[0]]
        neighborhood = neighborhood[df.shape[0]:]
        new_dic[k] = df
    
    df = None
    for k in new_dic.keys():
        if df is None:
            t = new_dic[k]
            t['gene'] = [k]*t.shape[0]
            df = t
        else:
            t = new_dic[k]
            t['gene'] = [k]*t.shape[0]
            df = pd.concat([df, t])
            
    n_clusters = len(np.unique(adata.obs['leiden'].tolist()))
    rna_neighbor_exp = np.zeros((n_clusters, n_markers_msc))
    genes = []
    i = 0
    markers_l = []
    for k in new_dic.keys():
        genes.append(k)
        for j in range(n_clusters):
             rna_neighbor_exp[j,i] = sum(item==j for item in new_dic[k]['cluster'].tolist())
        i = i + 1
    corr_l = []
    for i in range(n_clusters-1):
        if df.loc[df['cluster']==i].shape[0]<10:
            continue
        corr_l.append(proximity_network(df.loc[df['cluster']==i], n_neighbors=10))
    with open(os.path.join(out_dir, name+' neighborhoods_10_neighbors.pkl'), 'wb') as f:
        pickle.dump(corr_l, f)
# Out:
#   0%|                                                                                          | 0/120 [00:00<?, ?it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   1%|▋                                                                                 | 1/120 [00:00<01:05,  1.82it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   2%|██                                                                                | 3/120 [00:01<00:38,  3.04it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   4%|███▍                                                                              | 5/120 [00:01<00:30,  3.75it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   6%|████▊                                                                             | 7/120 [00:01<00:24,  4.53it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   8%|██████▏                                                                           | 9/120 [00:02<00:24,  4.53it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   9%|███████▍                                                                         | 11/120 [00:02<00:23,  4.64it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  11%|████████▊                                                                        | 13/120 [00:02<00:21,  4.99it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  12%|██████████▏                                                                      | 15/120 [00:03<00:21,  4.98it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  14%|███████████▍                                                                     | 17/120 [00:03<00:18,  5.49it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  16%|████████████▊                                                                    | 19/120 [00:04<00:19,  5.14it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  18%|██████████████▏                                                                  | 21/120 [00:04<00:19,  5.01it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  19%|███████████████▌                                                                 | 23/120 [00:04<00:20,  4.76it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  21%|████████████████▉                                                                | 25/120 [00:05<00:24,  3.90it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  22%|██████████████████▏                                                              | 27/120 [00:05<00:20,  4.62it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  24%|███████████████████▌                                                             | 29/120 [00:06<00:17,  5.18it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  26%|████████████████████▉                                                            | 31/120 [00:06<00:17,  5.10it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  28%|██████████████████████▎                                                          | 33/120 [00:06<00:15,  5.65it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  29%|███████████████████████▋                                                         | 35/120 [00:07<00:13,  6.11it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  31%|████████████████████████▉                                                        | 37/120 [00:07<00:12,  6.68it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  32%|██████████████████████████▎                                                      | 39/120 [00:07<00:11,  6.80it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  34%|███████████████████████████▋                                                     | 41/120 [00:07<00:11,  7.12it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  36%|█████████████████████████████                                                    | 43/120 [00:08<00:11,  6.78it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  38%|██████████████████████████████▍                                                  | 45/120 [00:08<00:10,  7.43it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  39%|███████████████████████████████▋                                                 | 47/120 [00:08<00:10,  6.90it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  41%|█████████████████████████████████                                                | 49/120 [00:09<00:10,  6.74it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  42%|██████████████████████████████████▍                                              | 51/120 [00:09<00:09,  7.45it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  44%|███████████████████████████████████▊                                             | 53/120 [00:09<00:09,  7.09it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  46%|█████████████████████████████████████▏                                           | 55/120 [00:09<00:09,  6.66it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  48%|██████████████████████████████████████▍                                          | 57/120 [00:10<00:11,  5.70it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  49%|███████████████████████████████████████▊                                         | 59/120 [00:10<00:11,  5.38it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  51%|█████████████████████████████████████████▏                                       | 61/120 [00:11<00:09,  5.94it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  52%|██████████████████████████████████████████▌                                      | 63/120 [00:11<00:09,  5.92it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  54%|███████████████████████████████████████████▉                                     | 65/120 [00:11<00:08,  6.69it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  56%|█████████████████████████████████████████████▏                                   | 67/120 [00:11<00:06,  7.60it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  57%|██████████████████████████████████████████████▌                                  | 69/120 [00:12<00:06,  7.99it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  59%|███████████████████████████████████████████████▉                                 | 71/120 [00:12<00:06,  8.08it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  61%|█████████████████████████████████████████████████▎                               | 73/120 [00:12<00:07,  6.51it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  62%|██████████████████████████████████████████████████▋                              | 75/120 [00:13<00:06,  6.68it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  64%|███████████████████████████████████████████████████▉                             | 77/120 [00:13<00:08,  5.22it/s]C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:13<00:00,  8.73it/s]

# %% [markdown]
# # Patch z-score

# %%
cluster_dir = r'..\results\HCH\patches'
out_dir = r'..\results\HCH\neighborhood_networks\z_scores'
fn_l = os.listdir(cluster_dir)
fn_l.sort()

# %%
for fn in fn_l:
    if fn.endswith('.pkl'):
        cell_id = fn.split(' ')[0]
        patch_expression = pd.read_pickle(os.path.join(cluster_dir, fn))['expression']
        z_score = (patch_expression-patch_expression.mean())/patch_expression.std()
        with open(os.path.join(out_dir, cell_id+' patch_z-score.pkl'), 'wb') as f:
            pickle.dump(z_score, f)

# %% [markdown]
# # Subcellular Network Variance

# %%
bm_in_dir = r'..\results\HBM\neighborhood_networks'
uc_in_dir1 = r'..\results\HUC\neighborhood_networks'
# uc_in_dir2 = r'..\results\HUC\neighborhood_networks'
hch_in_dir = r'..\results\HCH\neighborhood_networks'

# %%
markers = ['GAPDH','ACTB','IL8','IL6','CCL11','SOX9','RUNX1','SPP1','EEF2','PDL1','COL1A1','NANOG']
pairs = []

for i in range(len(markers)):
    for j in range(len(markers)):
        if markers[i]!=markers[j] and (not ((markers[i]+'_'+markers[j] in pairs) or (markers[j]+'_'+markers[i] in pairs))):
            pairs.append(markers[i]+'_'+markers[j])

# %%
fn_l = os.listdir(bm_in_dir)
fn_l.sort()

# %%
fn = fn_l[0]
l = pd.read_pickle(os.path.join(bm_in_dir, fn))
len(l)
temp = []
mean = np.zeros(len(pairs))
std = np.zeros(len(pairs))
for j in range(len(pairs)):
    gene1,gene2 = pairs[j].split('_')
    temp.append([])
    for i in range(len(l)):
        if (gene1 in l[i].columns.tolist()) and (gene2 in l[i].columns.tolist()):
            temp[j].append(l[i].loc[gene1,gene2])
    # print(pairs[j]+' interactions: '+str(len(temp[j]))+' Mean interaction: '+str(np.mean(np.array(temp[j])))+'Std interaction: '+str(np.std(np.array(temp[j]))))
    mean[j] = np.mean(np.array(temp[j]))
    std[j] = np.std(np.array(temp[j]))
# print(np.mean(temp, axis=0).shape)
# print(np.std(temp, axis=0).shape)
# m = np.mean(temp, axis=0)
# s = np.std(temp, axis=0)
# print(np.concatenate((m,s)).shape)
# Out:
# GAPDH_ACTB interactions: 44 Mean interaction: -0.19143909756596053Std interaction: 0.3285884668629548
# GAPDH_IL8 interactions: 7 Mean interaction: 0.09384058658719878Std interaction: 0.24459112828227753
# GAPDH_IL6 interactions: 37 Mean interaction: -0.10431284188106525Std interaction: 0.23129971973108746
# GAPDH_CCL11 interactions: 8 Mean interaction: -0.13065448008633296Std interaction: 0.2753286459252126
# GAPDH_SOX9 interactions: 18 Mean interaction: -0.09014791705758267Std interaction: 0.2248795004087054
# GAPDH_RUNX1 interactions: 28 Mean interaction: -0.10631573911336348Std interaction: 0.28083058264924543
# GAPDH_SPP1 interactions: 16 Mean interaction: -0.12492713862315549Std interaction: 0.19670767640185638
# GAPDH_EEF2 interactions: 44 Mean interaction: -0.28988864832007427Std interaction: 0.26131388327727806
# GAPDH_PDL1 interactions: 3 Mean interaction: -0.13990312581104528Std interaction: 0.14635933791094943
# GAPDH_COL1A1 interactions: 38 Mean interaction: -0.3774631891218087Std interaction: 0.2768890845720797
# GAPDH_NANOG interactions: 2 Mean interaction: -0.09705792560637226Std interaction: 0.10802384212610223
# ACTB_IL8 interactions: 7 Mean interaction: -0.017562598379855205Std interaction: 0.35681685742067926
# ACTB_IL6 interactions: 37 Mean interaction: -0.15589320860246358Std interaction: 0.20684162729448288
# ACTB_CCL11 interactions: 8 Mean interaction: 0.061044024232907806Std interaction: 0.34425800792565986
# ACTB_SOX9 interactions: 18 Mean interaction: -0.1237320627290598Std interaction: 0.28359562104375463
# ACTB_RUNX1 interactions: 28 Mean interaction: -0.1773498543594386Std interaction: 0.3011883835162793
# ACTB_SPP1 interactions: 16 Mean interaction: -0.1397768750389477Std interaction: 0.2716143174495564
# ACTB_EEF2 interactions: 44 Mean interaction: -0.24756780941461276Std interaction: 0.22260451179621807
# ACTB_PDL1 interactions: 3 Mean interaction: 0.009869599049807566Std interaction: 0.052992997569431245
# ACTB_COL1A1 interactions: 38 Mean interaction: -0.3998337392099991Std interaction: 0.19057784953271964
# ACTB_NANOG interactions: 2 Mean interaction: -0.12218170672714157Std interaction: 0.11166674654942702
# IL8_IL6 interactions: 5 Mean interaction: -0.040243236781504065Std interaction: 0.08494391610345545
# IL8_CCL11 interactions: 2 Mean interaction: 0.5167346460193932Std interaction: 0.21324615668595118
# IL8_SOX9 interactions: 4 Mean interaction: -0.0010857266659539816Std interaction: 0.2730869731046777
# IL8_RUNX1 interactions: 3 Mean interaction: -0.2297479831910018Std interaction: 0.24415333593402982
# IL8_SPP1 interactions: 3 Mean interaction: 0.048304032357182634Std interaction: 0.4656843837627576
# IL8_EEF2 interactions: 7 Mean interaction: 0.08326191275830741Std interaction: 0.27062241546290794
# IL8_PDL1 interactions: 1 Mean interaction: -0.07142857142857133Std interaction: 0.0
# IL8_COL1A1 interactions: 6 Mean interaction: -0.14988683304783534Std interaction: 0.08354276803046
# IL8_NANOG interactions: 0 Mean interaction: nanStd interaction: nan
# IL6_CCL11 interactions: 6 Mean interaction: 0.12512412136006498Std interaction: 0.38548769489232004
# IL6_SOX9 interactions: 15 Mean interaction: 0.10285220017233879Std interaction: 0.2936931220078935
# IL6_RUNX1 interactions: 23 Mean interaction: 0.02300455543650164Std interaction: 0.24108692624384556
# IL6_SPP1 interactions: 13 Mean interaction: -0.052033415927641165Std interaction: 0.10430996532830528
# IL6_EEF2 interactions: 37 Mean interaction: -0.06875265730158883Std interaction: 0.24920625403674118
# IL6_PDL1 interactions: 3 Mean interaction: -0.08698936337400005Std interaction: 0.04565233637829308
# IL6_COL1A1 interactions: 34 Mean interaction: -0.06377560713964818Std interaction: 0.25086537586809615
# IL6_NANOG interactions: 2 Mean interaction: -0.06273325644862136Std interaction: 0.008811687821170418
# CCL11_SOX9 interactions: 7 Mean interaction: 0.06370990035071544Std interaction: 0.3876212496891176
# CCL11_RUNX1 interactions: 7 Mean interaction: 0.0357035273771885Std interaction: 0.37744086599722604
# CCL11_SPP1 interactions: 5 Mean interaction: -0.04237639361918074Std interaction: 0.19929607232573218
# CCL11_EEF2 interactions: 8 Mean interaction: -0.04963632453986902Std interaction: 0.22720184708082167
# CCL11_PDL1 interactions: 2 Mean interaction: -0.07494109903784787Std interaction: 0.011769897914564072
# CCL11_COL1A1 interactions: 6 Mean interaction: 0.08773603578769774Std interaction: 0.4067186750886027
# CCL11_NANOG interactions: 0 Mean interaction: nanStd interaction: nan
# SOX9_RUNX1 interactions: 12 Mean interaction: 0.13121988358517195Std interaction: 0.3398511896340402
# SOX9_SPP1 interactions: 10 Mean interaction: 0.2912696668555667Std interaction: 0.3917924346946037
# SOX9_EEF2 interactions: 18 Mean interaction: -0.027022835259562773Std interaction: 0.19109593107444545
# SOX9_PDL1 interactions: 3 Mean interaction: -0.04497365313396443Std interaction: 0.018380672982332567
# SOX9_COL1A1 interactions: 15 Mean interaction: 0.01518198246986254Std interaction: 0.2888715792026679
# SOX9_NANOG interactions: 1 Mean interaction: -0.027623197959012587Std interaction: 0.0
# RUNX1_SPP1 interactions: 12 Mean interaction: 0.06142192157509787Std interaction: 0.2740788632256218
# RUNX1_EEF2 interactions: 28 Mean interaction: -0.06761591042427069Std interaction: 0.21352635956093477
# RUNX1_PDL1 interactions: 2 Mean interaction: -0.05739799474382568Std interaction: 0.01051359141108097
# RUNX1_COL1A1 interactions: 24 Mean interaction: -0.006668629691476182Std interaction: 0.3063596004860824
# RUNX1_NANOG interactions: 2 Mean interaction: 0.34902572996159814Std interaction: 0.39162465218930587
# SPP1_EEF2 interactions: 16 Mean interaction: 0.1078304094339343Std interaction: 0.2106078127972966
# SPP1_PDL1 interactions: 1 Mean interaction: -0.07611264707358861Std interaction: 0.0
# SPP1_COL1A1 interactions: 12 Mean interaction: -0.02332263990244253Std interaction: 0.15766085148559744
# SPP1_NANOG interactions: 2 Mean interaction: -0.06686411371842677Std interaction: 0.005580093385385061
# EEF2_PDL1 interactions: 3 Mean interaction: 0.28679151873647857Std interaction: 0.19502686108472314
# EEF2_COL1A1 interactions: 38 Mean interaction: -0.21159776130609617Std interaction: 0.21074549368965428
# EEF2_NANOG interactions: 2 Mean interaction: -0.08499247553661403Std interaction: 0.04274818190559056
# PDL1_COL1A1 interactions: 3 Mean interaction: -0.16153544357218078Std interaction: 0.08001953130314354
# PDL1_NANOG interactions: 0 Mean interaction: nanStd interaction: nan
# COL1A1_NANOG interactions: 1 Mean interaction: 0.15018724525495367Std interaction: 0.0
# C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\numpy\core\fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\numpy\core\_methods.py:263: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims, where=where)
# C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\numpy\core\_methods.py:223: RuntimeWarning: invalid value encountered in true_divide
#   subok=False)
# C:\Users\zfang38\Anaconda3\envs\scenv\lib\site-packages\numpy\core\_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
t = l[0]

# %%
fn_l = os.listdir(bm_in_dir)
bm_cell_id = []
bm_arr = []
for fn in tqdm(fn_l):
    bm_cell_id.append(fn.split(' ')[0])
    l = pd.read_pickle(os.path.join(bm_in_dir, fn))
    temp = []
    m = np.zeros(len(pairs))
    s = np.zeros(len(pairs))
    for j in range(len(pairs)):
        gene1,gene2 = pairs[j].split('_')
        temp.append([])
        for i in range(len(l)):
            if (gene1 in l[i].columns.tolist()) and (gene2 in l[i].columns.tolist()):
                temp[j].append(l[i].loc[gene1,gene2])
        if len(temp[j])!=0:
            m[j] = np.mean(np.array(temp[j]))
            s[j] = np.std(np.array(temp[j]))
    bm_arr.append(np.concatenate((m,s)))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 237/237 [00:07<00:00, 33.55it/s]

# %%
fn_l = os.listdir(uc_in_dir1)
exp1_uc_cell_id = []
uc_arr = []
for fn in tqdm(fn_l):
    exp1_uc_cell_id.append(fn.split(' ')[0])
    l = pd.read_pickle(os.path.join(uc_in_dir1, fn))
    temp = []
    m = np.zeros(len(pairs))
    s = np.zeros(len(pairs))
    for j in range(len(pairs)):
        gene1,gene2 = pairs[j].split('_')
        temp.append([])
        for i in range(len(l)):
            if (gene1 in l[i].columns.tolist()) and (gene2 in l[i].columns.tolist()):
                temp[j].append(l[i].loc[gene1,gene2])
        if len(temp[j])!=0:
            m[j] = np.mean(np.array(temp[j]))
            s[j] = np.std(np.array(temp[j]))
    uc_arr.append(np.concatenate((m,s)))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 81/81 [00:04<00:00, 18.35it/s]

# %%
fn_l = os.listdir(uc_in_dir2)
exp2_uc_cell_id = []
for fn in tqdm(fn_l):
    exp2_uc_cell_id.append(fn.split(' ')[0])
    l = pd.read_pickle(os.path.join(uc_in_dir2, fn))
    temp = []
    m = np.zeros(len(pairs))
    s = np.zeros(len(pairs))
    for j in range(len(pairs)):
        gene1,gene2 = pairs[j].split('_')
        temp.append([])
        for i in range(len(l)):
            if (gene1 in l[i].columns.tolist()) and (gene2 in l[i].columns.tolist()):
                temp[j].append(l[i].loc[gene1,gene2])
        if len(temp[j])!=0:
            m[j] = np.mean(np.array(temp[j]))
            s[j] = np.std(np.array(temp[j]))
    uc_arr.append(np.concatenate((m,s)))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:02<00:00, 18.40it/s]

# %%
fn_l = os.listdir(hch_in_dir)
hch_cell_id = []
hch_arr = []
for fn in tqdm(fn_l):
    hch_cell_id.append(fn.split(' ')[0])
    l = pd.read_pickle(os.path.join(hch_in_dir, fn))
    temp = []
    m = np.zeros(len(pairs))
    s = np.zeros(len(pairs))
    for j in range(len(pairs)):
        gene1,gene2 = pairs[j].split('_')
        temp.append([])
        for i in range(len(l)):
            if (gene1 in l[i].columns.tolist()) and (gene2 in l[i].columns.tolist()):
                temp[j].append(l[i].loc[gene1,gene2])
        if len(temp[j])!=0:
            m[j] = np.mean(np.array(temp[j]))
            s[j] = np.std(np.array(temp[j]))
    hch_arr.append(np.concatenate((m,s)))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 247/247 [00:12<00:00, 19.66it/s]

# %%
bm_arr = np.array(bm_arr)
bm_arr = np.nan_to_num(bm_arr)
uc_arr = np.array(uc_arr)
hch_arr = np.array(hch_arr)

# %%
print('Number of bm cells: '+str(bm_arr.shape[0]))
print('Number of uc cells: '+str(uc_arr.shape[0]))
print('Number of hch cells: '+str(hch_arr.shape[0]))
# Out:
# Number of bm cells: 237
# Number of uc cells: 121
# Number of hch cells: 247

# %%
var_names = []
for item in pairs:
    var_names.append('mean_'+item)
for item in pairs:
    var_names.append('std_'+item)

# %%
cell_types = pd.Categorical(['HBM']*bm_arr.shape[0] + ['HUC']*uc_arr.shape[0] + ['HCH']*hch_arr.shape[0],ordered=True, categories=['HBM','HUC','HCH'])

# %%
var_adata = sc.AnnData(np.concatenate((bm_arr, uc_arr, hch_arr)))
var_adata.obs['Cell'] = bm_cell_id+exp1_uc_cell_id+exp2_uc_cell_id+hch_cell_id 
var_adata.var_names = var_names
var_adata.obs['cell_types'] = cell_types
var_adata.uns['cell_types_colors'] = ['#0000ff', '#ff0000', '#00ac00']

# %%
sc.pp.pca(var_adata)

# %%
sc.pp.neighbors(var_adata)
sc.tl.umap(var_adata)
sc.tl.leiden(var_adata, resolution=1)

# %%
var_adata
# Out:
# AnnData object with n_obs × n_vars = 605 × 132
#     obs: 'Cell', 'cell_types', 'leiden'
#     uns: 'cell_types_colors', 'pca', 'neighbors', 'umap', 'leiden', 'leiden_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
# Load h5ad file if already exists
var_adata = sc.read_h5ad(filename='.\\clustering of network variability.h5ad')

# %%
with rc_context({'figure.figsize': (6, 6), 'font.size':25, 'axes.edgecolor': '0.15', 'axes.linewidth': 1.25, 'axes.facecolor':'#FFFFFF'}):
    sc.pl.umap(var_adata, color=['leiden'], size=20, 
               add_outline=True, legend_loc='on data',
               legend_fontsize=20, legend_fontoutline=20, 
               frameon=True,  title='Clustering of Cells', save=' network mean and variance clustering.png')
# Out:
# WARNING: saving figure to file figures\umap network mean and variance clustering.png

# %%
with rc_context({'figure.figsize': (6, 6), 'font.size': 20, 'axes.edgecolor': '0.15', 'axes.linewidth': 1.25, 'axes.facecolor': '#FFFFFF'}):
    sc.pl.umap(var_adata, color=['cell_types'],
               legend_fontsize=20, legend_fontoutline=20, 
               frameon=True,  title='Network Variability', save=' spatial network variability cell type.png')
# Out:
# WARNING: saving figure to file figures\umap spatial network variability cell type.png

# %%
sc.pl.pca(var_adata, color=['cell_types'])

# %%
with rc_context({'figure.figsize': (6, 6), 'font.size':25, 'axes.edgecolor': '0.15', 'axes.linewidth': 1.25, 'axes.facecolor':'#FFFFFF'}):
    sc.pl.umap(var_adata, color=['leiden'], size=20,
               add_outline=True, legend_loc='on data',
               legend_fontsize=20, legend_fontoutline=20, 
               frameon=True,  title='Clustering of Cells', save=' network mean and variance clustering.png')
# Out:
# WARNING: saving figure to file figures\umap network mean and variance clustering.png

# %%
with rc_context({'figure.figsize': (6, 6), 'font.size':25, 'axes.edgecolor': '0.15', 'axes.linewidth': 1.25, 'axes.facecolor':'#FFFFFF'}):
    sc.pl.heatmap(var_adata, color=['leiden'], size=20, groups=['4'],
               add_outline=True, legend_loc='on data',
               legend_fontsize=20, legend_fontoutline=20, 
               frameon=True,  title='clustering of cells', save=' network mean and variance clustering.png')

# %%
save_name = os.path.join('clustering of network variability.h5ad')
var_adata.write(filename=save_name)

# %%
var_sep_data = {'Cell ID': var_adata.obs['Cell'].tolist(),
                  'Cluster': var_adata.obs['leiden'].tolist(),
                  'Cell types': var_adata.obs['cell_types'].tolist()
                 }
var_set_data = pd.DataFrame(var_sep_data)
# var_adata

# %%
with open('.\\network variance clustering v. cell type.pkl', 'wb') as f:
    pickle.dump(var_sep_data, f)

# %% [markdown]
# ### Edge type plotting

# %%
edge_cell_id = pd.read_csv(r'.\\cytokine_figures\\edge_secretors.csv')
edge_cell_id
# Out:
#               IL8          CCL11           Both
# 0   exp1_bm_030_2  exp1_bm_007_1  exp1_bm_005_4
# 1   exp1_bm_057_1  exp1_bm_013_1  exp1_bm_008_1
# 2   exp1_uc_011_2  exp1_bm_021_3  exp1_bm_025_3
# 3             NaN  exp1_bm_022_1  exp1_bm_032_1
# 4             NaN  exp1_bm_042_2  exp1_bm_036_1
# 5             NaN  exp1_bm_074_1  exp1_bm_036_2
# 6             NaN  exp1_bm_091_3  exp1_bm_072_1
# 7             NaN  exp1_uc_012_1  exp1_uc_001_1
# 8             NaN  exp1_uc_013_1  exp1_uc_003_2
# 9             NaN  exp1_uc_016_1  exp1_uc_008_1
# 10            NaN  exp1_uc_020_1  exp1_uc_014_1
# 11            NaN  exp1_uc_022_1  exp1_uc_016_2
# 12            NaN  exp1_uc_024_1  exp1_uc_023_1
# 13            NaN  exp1_uc_031_1  exp1_uc_026_1
# 14            NaN  exp1_uc_032_1  exp1_uc_027_1
# 15            NaN  exp1_uc_033_1  exp1_uc_028_3
# 16            NaN  exp1_uc_039_1  exp1_uc_044_2
# 17            NaN  exp1_uc_040_1  exp1_uc_054_1
# 18            NaN  exp1_uc_044_1  exp1_uc_067_1
# 19            NaN  exp1_uc_047_2  exp1_uc_067_2
# 20            NaN  exp1_uc_045_1  exp1_uc_069_1
# 21            NaN  exp1_uc_045_2  exp1_uc_076_1
# 22            NaN  exp1_uc_088_2  exp1_uc_080_1
# 23            NaN  exp2_uc_021_1  exp1_uc_088_1
# 24            NaN  exp2_uc_023_1            NaN

# %%
edge_cells = edge_cell_id['IL8'].tolist() + edge_cell_id['CCL11'].tolist() + edge_cell_id['Both'].tolist()
edge_indicator = []
for cell in var_adata.obs['Cell'].tolist():
    if cell in edge_cells:
        edge_indicator.append('Edge')
    else:
        edge_indicator.append('Non-edge')

# %%
edge_types = pd.Categorical(edge_indicator, ordered=True, categories=['Edge','Non-edge'])
var_adata.obs['edge_types'] = edge_types
var_adata.uns['edge_types_colors'] = ['#ee8f9c', '#729ed7']

# %%
with rc_context({'figure.figsize': (6, 6), 'font.size': 20, 'axes.edgecolor': '0.15', 'axes.linewidth': 1.25, 'axes.facecolor': '#FFFFFF'}):
    sc.pl.umap(var_adata, color=['edge_types'],
               legend_fontsize=20, legend_fontoutline=20, 
               frameon=True,  title='Network Variability', save='edge on network variability.png')
# Out:
# WARNING: saving figure to file figures\umapedge on network variability.png
