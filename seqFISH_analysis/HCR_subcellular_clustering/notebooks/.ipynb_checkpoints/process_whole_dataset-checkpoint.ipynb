# %%
import glob
import os
import sys
from itertools import cycle
from pathlib import Path, PureWindowsPath

import cv2
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tifffile
import skimage
import pandas as pd
from skimage.filters import threshold_li
from tqdm.notebook import tqdm, trange
from skimage import exposure, io
from joblib import Parallel, delayed
import napari

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_dir = r'Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines\subcellular_clustering\v2\bm'

# %% [markdown]
# # Extract data directory info

# %%
def get_info(img_folder):
    """Function returns the info from folder containing multi-cycle staigning on cell

    Args:
        img_folder (str) : imgage folder path to get information
        name_dict (dict) : three level dictionnary mapping cycle -> channel -> marker name

    Returns:
        pandas dataframe with information
    """
    images_path = []
    markers = []
    fovs = []
    cycles = []
    cell_types = []
    
    # Loop through image folder
    for (dirpath, dirnames, filenames) in os.walk(img_folder):
        for name in sorted(filenames):
            if "tif" in name and 'Mask' not in name:
                # Get information from image name
                marker = name.split('_')[1:4]
                path = os.path.join(dirpath, name)
                fov = dirpath.split('\\')[-1]
                cycle = name.split('_')[0][-1]
                cell_type = dirpath.split('\\')[-2]
                if cell_type == 'bm':
                    cell_type = 'HBM'
                elif cell_type == 'hch':
                    cell_type = 'HCH'
                elif cell_type == 'exp1_uc':
                    cell_type = 'HUC_1'
                elif cell_type == 'exp2_uc':
                    cell_type = 'HUC_2'
                markers.append(marker)
                images_path.append(path)
                fovs.append(fov)
                cycles.append(cycle)
                cell_types.append(cell_type)
    info = {
        "Marker": markers,
        "Path": images_path,
        "FOV": fovs,
        "Cycle": cycles,
        "Cell Type": cell_types
    }
    df = pd.DataFrame(info)

    return df

def get_masks_info(img_folder):
    """Function returns the info from folder containing multi-cycle staigning on cell

    Args:
        img_folder (str) : imgage folder path to get information
        name_dict (dict) : three level dictionnary mapping cycle -> channel -> marker name

    Returns:
        pandas dataframe with information
    """
    images_path = []
    fovs = []
    cell_types = []
    cell_ids = []
    
    # Loop through image folder
    for (dirpath, dirnames, filenames) in os.walk(img_folder):
        for name in sorted(filenames):
            if "tif" in name and 'Mask' in name:
                # Get information from image name
                path = os.path.join(dirpath, name)
                fov = dirpath.split('\\')[-1]
                cell_type = dirpath.split('\\')[-2]
                cell_id = name.split('_')[0][-1] 
                if cell_type == 'bm':
                    cell_type = 'HBM'
                elif cell_type == 'hch':
                    cell_type = 'HCH'
                elif cell_type == 'exp1_uc':
                    cell_type = 'HUC_1'
                elif cell_type == 'exp2_uc':
                    cell_type = 'HUC_2'
                images_path.append(path)
                fovs.append(fov)
                cell_types.append(cell_type)
                cell_ids.append(cell_id)
    info = {
        "Path": images_path,
        "FOV": fovs,
        "Cell Type": cell_types,
        "Cell Id": cell_ids
    }
    df = pd.DataFrame(info)

    return df

# %%
df = get_info(data_dir)

# %%
df
# Out:
#                       Marker  \
# 0       [gapdh, empty, actb]
# 1          [il8, il6, ccl11]
# 2     [col1a1, empty, nanog]
# 3         [sox9, eef2, spp1]
# 4       [empty, runx1, pdl1]
# ...                      ...
# 1229       [il8, il6, ccl11]
# 1230  [col5a2, col1a1, pdl1]
# 1231  [malat1, runx1, cxcr4]
# 1232   [empty, mki67, nanog]
# 1233        [ConA, PhA, WGA]
#
#                                                    Path  FOV Cycle Cell Type
# 0     Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  001     1       HBM
# 1     Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  001     2       HBM
# 2     Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  001     3       HBM
# 3     Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  001     4       HBM
# 4     Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  001     5       HBM
# ...                                                 ...  ...   ...       ...
# 1229  Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  028     3       HCH
# 1230  Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  028     4       HCH
# 1231  Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  028     5       HCH
# 1232  Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  028     6       HCH
# 1233  Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  028     7       HCH
#
# [1234 rows x 5 columns]

# %%
df['Cell Type'].unique()
# Out:
# array(['HBM', 'HUC_1', 'HUC_2', 'HCH'], dtype=object)

# %%
df_mask = get_masks_info(data_dir)

# %%
df_mask
# Out:
#                                                   Path  FOV Cell Type Cell Id
# 0    Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  001       HBM       1
# 1    Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  003       HBM       1
# 2    Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  003       HBM       2
# 3    Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  003       HBM       3
# 4    Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  004       HBM       1
# ..                                                 ...  ...       ...     ...
# 588  Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  027       HCH       0
# 589  Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  027       HCH       1
# 590  Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  028       HCH       1
# 591  Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  028       HCH       2
# 592  Y:\coskun-lab\Zhou\4_HCR\2D_analyses_pipelines...  028       HCH       3
#
# [593 rows x 4 columns]

# %%
df_mask['Cell Type'].unique()
# Out:
# array(['HBM', 'HUC_1', 'HUC_2', 'HCH'], dtype=object)

# %% [markdown]
# # Create merged mask

# %%
from joblib import Parallel, delayed

def read_img(path):
    img = skimage.io.imread(path)
    if len(img.shape) > 2:
        img = img[0, ...]
    return img 

def joblib_loop(task, pics):
    return Parallel(n_jobs=20)(delayed(task)(i) for i in pics)

# %%
group = df_mask.groupby(['Cell Type', 'FOV'])

# %%
for name, df_group in tqdm(group):
    paths = df_group.Path.tolist()
    cell_ids = df_group['Cell Id'].tolist()
    path = Path.cwd().parent / 'data' / 'masks2' / f'{name[0]}_{name[1]}.tiff'
    if os.path.exists(path):
        continue
    
    # Read all mask images
    imgs = joblib_loop(read_img, paths)
    
    # Define combined mask
    mask = np.zeros(imgs[0].shape, dtype=np.uint8)
    
    # Loop per cell mask ID
    for ii, cell_id in enumerate(cell_ids):
        mask = np.where(imgs[ii]>0, int(cell_id), mask)
    
    # Save mask
    skimage.io.imsave(path, mask)
# Out:
#   0%|          | 0/195 [00:00<?, ?it/s]
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_002.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_003.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_004.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_005.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_006.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_007.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_008.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_009.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_010.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_011.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_012.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_013.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_014.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_015.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_016.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_017.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_018.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_019.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_020.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_021.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_022.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_023.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_024.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_025.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_026.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_027.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HCH_028.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_001.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_002.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_003.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_004.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_005.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_006.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_007.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_008.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_011.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_012.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_013.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_014.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_015.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_016.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_017.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_018.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_019.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_020.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_021.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_022.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_023.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_024.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_025.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_026.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_027.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_028.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_029.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_031.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_032.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_033.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_034.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_039.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_040.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_042.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_044.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_046.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_047.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_049.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_050.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_053.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_054.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_057.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_059.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_063.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_065.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_066.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_067.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_069.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_076.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_077.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_079.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_080.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_083.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_088.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_1_091.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_002.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_004.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_008.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_009.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_010.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_011.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_017.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_018.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_019.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_021.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_023.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_024.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_028.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_030.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_031.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_032.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_033.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_034.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_035.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_036.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_037.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_039.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_040.tiff is a low contrast image
#   skimage.io.imsave(path, mask)
# C:\Users\thu71\AppData\Local\Temp/ipykernel_72112/2145918569.py:19: UserWarning: Y:\coskun-lab\Thomas\HCR_subcellular_clustering\data\masks2\HUC_2_043.tiff is a low contrast image
#   skimage.io.imsave(path, mask)

# %% [markdown]
# # Read pixel level info

# %%
from joblib import Parallel, delayed
from skimage import exposure, io

def contrast_streching(img, n_min=20, n_max=99.9):
    if len(img.shape)>2:
        img = img[0,...,1:]
    p2, p98 = np.percentile(img, (n_min, n_max))
    return exposure.rescale_intensity(
        img, in_range=(p2, p98), out_range=(0, 1)
    )

def read_img(path):
    return contrast_streching(skimage.io.imread(path))

def joblib_loop(task, pics):
    return Parallel(n_jobs=20)(delayed(task)(i) for i in pics)

# %%
group = df.groupby(['Cell Type', 'FOV'])

# %%
for name, df_group in tqdm(group):
    df_appended = []

    paths = df_group.Path.tolist()
    markers = df_group['Marker'].tolist()
    
    # Get Cell mask
    path = Path.cwd().parent / 'data' / 'masks2' / f'{name[0]}_{name[1]}.tiff'
    if not os.path.exists(path):
        continue
    mask_cell = skimage.io.imread(path)
    
    # Read all mask images
    imgs = joblib_loop(read_img, paths)
    
    # Get imgs and markers flatten
    imgs_flatten = []
    markers_flatten = []
    for ii, marker_list in enumerate(markers):
        for jj, marker in enumerate(marker_list):
            if marker == 'empty':
                continue
            img = contrast_streching(imgs[ii][...,jj])
            imgs_flatten.append(img)
            markers_flatten.append(marker)
    
    # Get all intensity mask
    imgs_stack = np.stack(imgs_flatten)
    mask_intensity = (imgs_stack < 0.3).all(0)

    for cell_id in np.unique(mask_cell):
        if cell_id == 0:
            continue
        
        # Get combined mask
        mask_combined = cv2.bitwise_and(~mask_intensity.astype(int), (mask_cell==cell_id).astype(int))

        # Get pixel intensity
        rows, cols = np.where(mask_combined)
        cell_pixels = imgs_stack[:, rows, cols]

        # Create dataframe
        df_pixels = pd.DataFrame(cell_pixels.T, columns=markers_flatten)
        df_pixels["Cell Type"] = name[0]
        df_pixels["FOV"] = name[1]
        df_pixels["X"] = rows
        df_pixels["Y"] = cols
        df_pixels["Id"] = cell_id
        df_appended.append(df_pixels)
    df_pixels = pd.concat(df_appended, ignore_index=True)
    
    path = Path.cwd().parent / 'data' / 'h5' / f'{name[0]}_{name[1]}.h5'
    df_pixels.to_hdf(path, 'df', mode='w', format='table', data_columns=True)
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]
# C:\Users\thu71\.conda\envs\thomas-env\lib\site-packages\tables\path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Cell Type'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\thu71\.conda\envs\thomas-env\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Cell Type_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\thu71\.conda\envs\thomas-env\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Cell Type_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\thu71\.conda\envs\thomas-env\lib\site-packages\tables\attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Cell Type_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
